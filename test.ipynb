# %%
from kokoro import KPipeline
from IPython.display import display, Audio
import soundfile as sf
import torch

pipeline = KPipeline(lang_code='h')
text = ext = (
    "ट्रांसपोर्टरों की हड़ताल लगातार पांचवें दिन जारी, दिसंबर से इलेक्ट्रॉनिक टोल कलेक्शनल सिस्टम"
)
generator = pipeline(text,voice='af_heart')

for i ,(gs,ps,audio) in enumerate(generator):
    print(i,gs,ps)
    display(Audio(data=audio,rate=24000,autoplay=i==0))
    sf.write(f'{i}.wav', audio, 24000)
# Out:
# WARNING: Defaulting repo_id to hexgrad/Kokoro-82M. Pass repo_id='hexgrad/Kokoro-82M' to suppress this warning.
# 0 ट्रांसपोर्टरों की हड़ताल लगातार पांचवें दिन जारी, दिसंबर से इलेक्ट्रॉनिक टोल कलेक्शनल सिस्टम ʈɾˌãspˈoːɾʈəɾˌõ ki hˌər.tˈaːl lˌəɡaːtˈaːɾ pˈãcʋˌẽː dˈɪn ɟˈaːɾi, dɪsˈʌmbəɾ seː ɪlˈeːkʈɾɔnˌɪk ʈˈoːl kəlˈeːkʃənˌəl sˈɪsʈəm
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
